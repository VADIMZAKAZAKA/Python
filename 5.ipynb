# %%
n = int(input())
sum = 0
for k in range(1, n+1):
    sum += 1/2**n

print(sum)
# Out:
#  3
# 0.375

# %%
import math 
n = int(input())
x = int(input())
sum = 0 
for k in range(1, n+1):
    sum += (math.cos(x) ** k)/k

print(sum)
# Out:
#  4
#  5
# 0.3331211467854632

# %%
n = int(input())
sum = 0
for k in range(0, n):
    sum += -1**n * 3**n
    print(sum)
# Out:
#  5
# -243
# -486
# -729
# -972
# -1215

# %%
import math
n = int(input())
sum = 0
for n in range(1, n):
    sum = 1 / math.sin(n)
    print(sum)
# Out:
#  2
# 1.1883951057781212

# %%
n = int(input())
sum = 1
for k in range(1, n+1):
    sum += -1**n+1 * n**3
    print(sum)
# Out:
#  4
# 64
# 127
# 190
# 253
