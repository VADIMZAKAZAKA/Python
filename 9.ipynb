# %%
1 
s = input().split()
print(len(s))
# Out:
#  Привет мир
# 2

# %%
2 
s = input().split()
count = 0
for word in s:
    if word[0] == word[-1]:
        count += 1
print(count)
# Out:
#  африка арбуз аппарат антланта
# 2

# %%
3 
s = input().split()
count = 0
for word in s:
    if 'а' or 'А' in word:
        count += 1
print(count)
# Out:
#  Алфавит прекрасная штука как и аппарат атланта
# 7

# %%
Алфавит прекрасная штука как и аппарат атланта

# %%
4
s = input().split()
print(len(min(s, key=len)))
# Out:
#  Алфавит прекрасная штука как и аппарат атланта
# 1

# %%
5 
s = input().split()
print(' '.join(reversed(s)))
# Out:
#  Алфавит прекрасная штука как и аппарат атланта
# атланта аппарат и как штука прекрасная Алфавит

# %%
6 
s = input().split()
s.sort()
print(' '.join(s))
# Out:
#  Алфавит прекрасная штука как и аппарат атланта
# Алфавит аппарат атланта и как прекрасная штука

# %%
7
с = input()
S = input()
S0 = input()

result = ''
for k in S:
    if k == с:
        result += S0
    result += k
print(result)
# Out:
#  Алфавит прекрасная штука как и аппарат атланта
#  Алфавит прекрасная штука как и аппарат атланта с десятью строками
#  Алфавит прекрасная штука как и аппарат атланта с десятью строками и со слоновой костью
# Алфавит прекрасная штука как и аппарат атланта с десятью строками

# %%
Алфавит прекрасная штука как и аппарат атланта
Алфавит прекрасная штука как и аппарат атланта с десятью строками
Алфавит прекрасная штука как и аппарат атланта с десятью строками и со слоновой костью

# %%
8
s = input().split()
print(' '.join(s))
# Out:
#  Алфавит   прекрасная штука как и аппарат атланта
# Алфавит прекрасная штука как и аппарат атланта

# %%
9
s = input()
count = 0
for char in s:
    if 'а' <= char <= 'я':
        count += 1
print(count)
# Out:
#  Алфавит прекрасная штука как и аппарат атланта
# 39

# %%
10
s = input().split()
longest = len(s[0])
for word in s:
    if len(word) > longest:
        longest = len(word)
print(longest)
# Out:
#  Алфавит прекрасная штука как и аппарат атланта
# 10

# %%
11
s = input()
e = s[::2]      # чётные индексы
o = s[1::2]      # нечётные индексы
result = e + o[::-1]
print(result)
# Out:
#  Алфавит прекрасная штука как и аппарат атланта с десятью строками и со слоновой костью
# Афвтперса тк а  паа тат  еяь тоаиис лнвйксьюто ооосо  мкрсютсдсанлатрпаиккаушянакр иал

# %%
12
S = input()
N = int(input())
star = '*' * N
print(star.join(S))
# Out:
#  Алфавит прекрасная штука как и аппарат атланта с десятью строками и со слоновой костью
#  12
# ...

# %%
13
s = input().split()
print('.'.join(s))
# Out:
#  Алфавит прекрасная штука как и аппарат атланта с десятью строками и со слоновой костью
# Алфавит.прекрасная.штука.как.и.аппарат.атланта.с.десятью.строками.и.со.слоновой.костью

# %%
s = input()

filename_with_ext = s.split('\\')[-1]

filename = filename_with_ext.rsplit('.', 1)[0]
print(filename)
# Out:
#  d:\ivanov\primer\prog.py
# prog

# %%
s = input().split()
longest_word = ''
for word in s:
    if len(word) >= len(longest_word):
        longest_word = word
print(longest_word)
# Out:
#  Алфавит прекрасная штука как и аппарат атланта с десятью строками и со слоновой костью
# прекрасная
