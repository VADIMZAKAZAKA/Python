# %%
import math
a = int(input())
b = int(input())
c = int(input())
V = a*b*c
S = 2*(a*b+b*c+a*c)
print(V)
print(S)
# Out:
#  2
#  3
#  4
# 24
# 52

# %%
import math
a = int(input())
b = int(input())
c = int(input())
V = a*b*c
S = 2*(a*b+b*c+a*c)
print(V)
print(S)
# Out:
#  1
#  2
#  3
# 6
# 22

# %%
a = int(input())
b = int(input())
c = (a**2 + b**2)**0.5
P = a + b + c
print(c, P)
# Out:
#  2
#  3
# 3.605551275463989 8.60555127546399

# %%
import math
R1 = float(input())
R2 = float(input())
S1 = math.pi * R1**2
S2 = math.pi * R2**2
S3 = S1 - S2
print(S1, S2, S3)
# Out:
#  1
#  2
# 3.141592653589793 12.566370614359172 -9.42477796076938

# %%
x1 = int(input())
x2 = int(input())
y1 = int(input())
y2 = int(input())
a = abs(x2 - x1)
b = abs(y2 - y1)
P = 2 * (a + b)
S = a * b
print(P, S)
# Out:
#  1
#  2
#  3
#  4
# 4 1

# %%
x1 = int(input())
x2 = int(input())
y1 = int(input())
y2 = int(input())
d = ((x2 - x1)**2 + (y2 - y1)**2)**0.5
print(d)
# Out:
#  1
#  2
#  4
#  5
# 1.4142135623730951

# %%
x1 = int(input())
x2 = int(input())
x3 = int(input())
y1 = int(input())
y2 = int(input())
y3 = int(input())

a = ((x2 - x1)**2 + (y2 - y1)**2)**0.5
b = ((x3 - x2)**2 + (y3 - y2)**2)**0.5
c = ((x1 - x3)**2 + (y1 - y3)**2)**0.5

P = a + b + c
p = P/2
S = (p*(p - a)*(p - b)*(p - c))**0.5

print(P, S)
# Out:
#  1
#  2
#  3
#  4
#  5
#  6
# 5.656854249492381 0.0

# %%
Tf = float(input())
Tc = (Tf - 32) * 5 / 9
print(Tc)
# Out:
#  2
# -16.666666666666668

# %%
X = float(input())
A = float(input())
Y = float(input())
B = float(input())

price_chocolate = A/X
price_caramel = B/Y
ratio = price_chocolate / price_caramel

print(price_chocolate, price_caramel, ratio)
# Out:
#  4
#  5
#  6
#  7
# 1.25 1.1666666666666667 1.0714285714285714

# %%
nomber = 10

# %%
import math
a = float(input())
rad = a * math.pi / 180
print(rad)
# Out:
#  45
# 0.7853981633974483

# %%
V1 = float(input())
V2 = float(input())
S = float(input())
T = float(input())
distance = S + (V1 + V2) * T
print(distance)
# Out:
#  3
#  5
#  9
#  12
# 105.0

# %%
A = float(input())
B = float(input())
C = float(input())
AC = abs(C - A)
BC = abs(C - B)
sum_AC_BC = AC + BC
print(AC, BC, sum_AC_BC)
# Out:
#  5
#  6
#  7
# 2.0 1.0 3.0

# %%
a = float(input())
b = float(input())
sum_sq = a**2 + b**2
diff_sq = a**2 - b**2
prod_sq = a**2 * b**2
quot_sq = a**2 / b**2
print(sum_sq, diff_sq, prod_sq, quot_sq)
# Out:
#  5
#  6
# 61.0 -11.0 900.0 0.6944444444444444

# %%
V = float(input())
U = float(input())
T1 = float(input())
T2 = float(input())
path_lake = V * T1
path_river = (V - U) * T2
total_path = path_lake + path_river
print(total_path)
# Out:
#  2
#  3
#  4
#  5
# 3.0
