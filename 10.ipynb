# %%
1
s = input()
freq = {}
for char in s:
    freq[char] = freq.get(char, 0) + 1
print(freq)
# Out:
#  Алфавит прекрасная штука как и аппарат атланта с десятью строками и со слоновой костью
# {'А': 1, 'л': 3, 'ф': 1, 'а': 12, 'в': 2, 'и': 4, 'т': 8, ' ': 13, 'п': 3, 'р': 4, 'е': 2, 'к': 6, 'с': 7, 'н': 3, 'я': 2, 'ш': 1, 'у': 1, 'д': 1, 'ь': 2, 'ю': 2, 'о': 6, 'м': 1, 'й': 1}

# %%
2 Получите строку, состоящую из первых двух и последних двух символов заданной строки. Если длина строки меньше двух, то выведите соответствующее сообщение.

# %%
2
s = input()
if len(s) < 2:
    print("Длина строки меньше двух")
else:
    result = s[:2] + s[-2:]
    print(result)
# Out:
#  Алфавит прекрасная штука как и аппарат атланта
# Алта
