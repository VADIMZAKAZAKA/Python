# %%
x = int(input())
a = int(input())
if x > 0:
    y = a * x**2
else:
    y = a * x - 1
print(y)
# Out:
#  2
#  4
# 16.0

# %%
x = int(input())
a = int(input())
if x >= 1:
    y = a * x + 1
else:
    y = x**2 - 1
print(y)
# Out:
#  2
#  3
# 7.0

# %%
x = int(input())
a = int(input())
if x < 0:
    y = 3*(a**2)
else:
    y = 4*a*x-1
print(y)
# Out:
#  2
#  3
# 23

# %%
x = int(input())
a = int(input())
if x > 4:
    y = 2*(a**2)
else:
    y = 3*x-1
print(y)
# Out:
#  2
#  3
# 5

# %%
x = int(input())
a = int(input())
if x > 2:
    y = 2*a*(x**2) - 1
else:
    y = x
print(y)
# Out:
#  3
#  4
# 71

# %%
x = int(input())
a = int(input())
if x > 2:
    y = x**2
else:
    y = 2*a-1
print(y)
# Out:
#  2
#  3
# 5

# %%
import math
x = int(input())
a = int(input())
if x > 2:
    y = math.cos(2*x-1)
else:
    y = math.sin(3*x+1)
print(y)
# Out:
#  2
#  1
# 0.6569865987187891

# %%
import math
x = int(input())
a = int(input())
if x > 2:
    y = 2*x**3 - 2*x - 1
else:
    y = 3*x**2 - 2*x + 1
print(y)
# Out:
#  2
#  3
# 9

# %%
import math
x = int(input())
a = int(input())
if x > 1:
    y = a*math.sqrt(x) + 1
else:
    y = 1/a
print(y)
# Out:
#  1
#  2
# 0.5

# %%
import math
x = int(input())
a = int(input())
if x >= 0:
    y = math.sqrt(x)+1
else:
    y = a/x-1
print(y)
# Out:
#  2
#  3
# 2.414213562373095

# %%
import math
x = int(input())
a = int(input())
if x > 0:
    y = 1/x + a
else:
    y = x**2 - 1
print(y)
# Out:
#  2
#  3
# 3.5

# %%
import math
x = int(input())
a = int(input())
if x > math.pi/2:
    y = math.cos(x)
else:
    y = math.sin(x)
print(y)
# Out:
#  2
#  3
# -0.4161468365471424

# %%
import math
x = int(input())
a = int(input())
if x > 2:
    y = math.sqrt(x-2)
else:
    y = (x-2)**2+1
print(y)
# Out:
#  2
#  3
# 1
