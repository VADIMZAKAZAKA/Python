# %%
# 1
numbers = [5, -2, 13, 8, -7, 20, 15, -4, 25, 10, -12, 30]
result = sorted([x for x in numbers if x % 2 == 1], reverse=True)
print("1:", result)
# Out:
# 1: [25, 15, 13, 5, -7]

# %%
# 2
numbers = [5, -2, 13, 8, -7, 20, 15, -4, 25, 10, -12, 30]
result = sorted([x for x in numbers if x > 0])
print("2:", result)
# Out:
# 2: [5, 8, 10, 13, 15, 20, 25, 30]

# %%
# 3
numbers = [5, -2, 13, 8, -7, 20, 15, -4, 25, 10, -12, 30]
result = sorted([x for x in numbers if x > 0], reverse=True)
print("3:", result)
# Out:
# 3: [30, 25, 20, 15, 13, 10, 8, 5]

# %%
# 4
numbers = [5, -2, 13, 8, -7, 20, 15, -4, 25, 10, -12, 30]
result = sorted([x for x in numbers if x % 2 == 0])
print("4:", result)
# Out:
# 4: [-12, -4, -2, 8, 10, 20, 30]

# %%
# 5
numbers = [5, -2, 13, 8, -7, 20, 15, -4, 25, 10, -12, 30]
k = 10
result = sorted([x for x in numbers if x > k], reverse=True)
print("5:", result)
# Out:
# 5: [30, 25, 20, 15, 13]

# %%
# 6
numbers = [5, -2, 13, 8, -7, 20, 15, -4, 25, 10, -12, 30]
result = sorted([x for x in numbers if x > 10])
print("6:", result)
# Out:
# 6: [13, 15, 20, 25, 30]

# %%
# 7
numbers = [5, -2, 13, 8, -7, 20, 15, -4, 25, 10, -12, 30]
result = sorted([x for x in numbers if x % 5 == 0], reverse=True)
print("7:", result)
# Out:
# 7: [30, 25, 20, 15, 10, 5]

# %%
# 8
numbers = [5, -2, 13, 8, -7, 20, 15, -4, 25, 10, -12, 30]
k = 10
result = sorted([x for x in numbers if x < k])
print("8:", result)
# Out:
# 8: [-12, -7, -4, -2, 5, 8]

# %%
# 9
numbers = [5, -2, 13, 8, -7, 20, 15, -4, 25, 10, -12, 30]
result = sorted([x for x in numbers if x < 15], reverse=True)
print("9:", result)
# Out:
# 9: [13, 10, 8, 5, -2, -4, -7, -12]

# %%
# 10
numbers = [5, -2, 13, 8, -7, 20, 15, -4, 25, 10, -12, 30]
result = sorted([x for x in numbers if x % 3 == 0])
print("10:", result)
# Out:
# 10: [-12, 15, 30]

# %%
# 11
numbers = [5, -2, 13, 8, -7, 20, 15, -4, 25, 10, -12, 30]
k = 5
result = sorted([x for x in numbers if x % k == 0], reverse=True)
print("11:", result)
# Out:
# 11: [30, 25, 20, 15, 10, 5]

# %%
# 12
numbers = [5, -2, 13, 8, -7, 20, 15, -4, 25, 10, -12, 30]
result = sorted([x for x in numbers if x < 0])
print("12:", result)
# Out:
# 12: [-12, -7, -4, -2]

# %%
# 13
numbers = [5, -2, 13, 8, -7, 20, 15, -4, 25, 10, -12, 30]
result = sorted([numbers[i] for i in range(1, len(numbers), 2)], reverse=True)
print("13:", result)
# Out:
# 13: [30, 20, 10, 8, -2, -4]

# %%
# 14
numbers = [5, -2, 13, 8, -7, 20, 15, -4, 25, 10, -12, 30]
result = sorted([x for x in numbers if 10 <= x <= 99 or -99 <= x <= -10])
print("14:", result)
# Out:
# 14: [-12, 10, 13, 15, 20, 25, 30]

# %%
# 15
numbers = [5, -2, 13, 8, -7, 20, 15, -4, 25, 10, -12, 30]
result = sorted([numbers[i] for i in range(0, len(numbers), 2)])
print("15:", result)
# Out:
# 15: [-12, -7, 5, 13, 15, 25]
